# %% [markdown]
# <a href="https://colab.research.google.com/github/andreialuizafm/Aula-08/blob/main/Machine_Learning_Aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_table("/content/drive/MyDrive/Cursos/MachineLearn/fruit_data_with_colors_miss.txt")

# %%
data = pd.read_table("/content/drive/MyDrive/Cursos/MachineLearn/fruit_data_with_colors_miss.txt",na_values=['.','?'])

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype   mass  width  height  \
# 0             1      apple      granny_smith  192.0    8.4     7.3
# 1             1      apple      granny_smith  180.0    8.0     6.8
# 2             1      apple      granny_smith  176.0    7.4     7.2
# 3             2   mandarin          mandarin    NaN    6.2     4.7
# 4             2   mandarin          mandarin   84.0    6.0     4.6
# 5             2   mandarin          mandarin   80.0    5.8     4.3
# 6             2   mandarin          mandarin   80.0    5.9     4.3
# 7             2   mandarin               NaN   76.0    5.8     4.0
# 8             1      apple          braeburn  178.0    7.1     NaN
# 9             1      apple          braeburn  172.0    7.4     7.0
# 10            1      apple          braeburn  166.0    6.9     7.3
# 11            1      apple          braeburn  172.0    7.1     7.6
# 12            1      apple          braeburn  154.0    7.0     7.1
# ...

# %%
data.fillna(0)
# Out:
#     fruit_label fruit_name     fruit_subtype   mass  width  height  \
# 0             1      apple      granny_smith  192.0    8.4     7.3
# 1             1      apple      granny_smith  180.0    8.0     6.8
# 2             1      apple      granny_smith  176.0    7.4     7.2
# 3             2   mandarin          mandarin    0.0    6.2     4.7
# 4             2   mandarin          mandarin   84.0    6.0     4.6
# 5             2   mandarin          mandarin   80.0    5.8     4.3
# 6             2   mandarin          mandarin   80.0    5.9     4.3
# 7             2   mandarin                 0   76.0    5.8     4.0
# 8             1      apple          braeburn  178.0    7.1     0.0
# 9             1      apple          braeburn  172.0    7.4     7.0
# 10            1      apple          braeburn  166.0    6.9     7.3
# 11            1      apple          braeburn  172.0    7.1     7.6
# 12            1      apple          braeburn  154.0    7.0     7.1
# ...

# %%
data.describe()
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   58.000000  59.000000  58.000000    59.000000
# mean      2.542373  164.448276   7.105085   7.691379     0.762881
# std       1.208048   54.534770   0.816938   1.372830     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.500000   6.600000   7.200000     0.720000
# 50%       3.000000  159.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.500000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
data.fillna(data.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-7-3231489778.py in <cell line: 0>()
# ----> 1 data.fillna(data.mean())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
data['fruit_subtype'].value_counts().argmax()
# Out:
# np.int64(0)

# %%
data = data.fillna(data.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-476127175.py in <cell line: 0>()
# ----> 1 data = data.fillna(data.mean())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
data['fruit_subtype'] = data['fruit_subtype'].fillna(data['fruit_subtype'].value_counts().argmax())

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype   mass  width  height  \
# 0             1      apple      granny_smith  192.0    8.4     7.3
# 1             1      apple      granny_smith  180.0    8.0     6.8
# 2             1      apple      granny_smith  176.0    7.4     7.2
# 3             2   mandarin          mandarin    NaN    6.2     4.7
# 4             2   mandarin          mandarin   84.0    6.0     4.6
# 5             2   mandarin          mandarin   80.0    5.8     4.3
# 6             2   mandarin          mandarin   80.0    5.9     4.3
# 7             2   mandarin                 0   76.0    5.8     4.0
# 8             1      apple          braeburn  178.0    7.1     NaN
# 9             1      apple          braeburn  172.0    7.4     7.0
# 10            1      apple          braeburn  166.0    6.9     7.3
# 11            1      apple          braeburn  172.0    7.1     7.6
# 12            1      apple          braeburn  154.0    7.0     7.1
# ...

# %%
data.shape[0]
# Out:
# 59

# %%
data.isnull().sum() #Somatório de valores nulos
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             1
# width            0
# height           1
# color_score      0
# dtype: int64

# %%
data.isnull().sum()/data.shape[0]*100    #Porcentagem de valores nulos
# Out:
# fruit_label      0.000000
# fruit_name       0.000000
# fruit_subtype    1.694915
# mass             1.694915
# width            0.000000
# height           1.694915
# color_score      0.000000
# dtype: float64

# %%
data1 = data[['fruit_label','fruit_subtype','fruit_name','width','height','color_score']]
data1
# Out:
#     fruit_label     fruit_subtype fruit_name  width  height  color_score
# 0             1      granny_smith      apple    8.4     7.3         0.55
# 1             1      granny_smith      apple    8.0     6.8         0.59
# 2             1      granny_smith      apple    7.4     7.2         0.60
# 3             2          mandarin   mandarin    6.2     4.7         0.80
# 4             2          mandarin   mandarin    6.0     4.6         0.79
# 5             2          mandarin   mandarin    5.8     4.3         0.77
# 6             2          mandarin   mandarin    5.9     4.3         0.81
# 7             2                 0   mandarin    5.8     4.0         0.81
# 8             1          braeburn      apple    7.1     NaN         0.92
# 9             1          braeburn      apple    7.4     7.0         0.89
# 10            1          braeburn      apple    6.9     7.3         0.93
# 11            1          braeburn      apple    7.1     7.6         0.92
# ...

# %%
data2 = data[['mass','width','height','color_score']]
data2
# Out:
#      mass  width  height  color_score
# 0   192.0    8.4     7.3         0.55
# 1   180.0    8.0     6.8         0.59
# 2   176.0    7.4     7.2         0.60
# 3     NaN    6.2     4.7         0.80
# 4    84.0    6.0     4.6         0.79
# 5    80.0    5.8     4.3         0.77
# 6    80.0    5.9     4.3         0.81
# 7    76.0    5.8     4.0         0.81
# 8   178.0    7.1     NaN         0.92
# 9   172.0    7.4     7.0         0.89
# 10  166.0    6.9     7.3         0.93
# 11  172.0    7.1     7.6         0.92
# 12  154.0    7.0     7.1         0.88
# 13  164.0    7.3     7.7         0.70
# 14  152.0    7.6     7.3         0.69
# 15  156.0    7.7     7.1         0.69
# 16  156.0    7.6     7.5         0.67
# 17  168.0    7.5     7.6         0.73
# 18  162.0    7.5     7.1         0.83
# 19  162.0    7.4     7.2         0.85
# 20  160.0    7.5     7.5         0.86
# 21  156.0    7.4     7.4         0.84
# 22  140.0    7.3     7.1         0.87
# 23  170.0    7.6     7.9         0.88
# ...

# %%
data2.describe()
# Out:
#              mass      width     height  color_score
# count   58.000000  59.000000  58.000000    59.000000
# mean   164.448276   7.105085   7.691379     0.762881
# std     54.534770   0.816938   1.372830     0.076857
# min     76.000000   5.800000   4.000000     0.550000
# 25%    140.500000   6.600000   7.200000     0.720000
# 50%    159.000000   7.200000   7.600000     0.750000
# 75%    177.500000   7.500000   8.200000     0.810000
# max    362.000000   9.600000  10.500000     0.930000

# %%
#(Valor que queremos transformar - valor minimo da coluna ) / (valor maximo da coluna - valor minimo da coluna)

(25-12)/(59-12)
# Out:
# 0.2765957446808511

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler()

# %%
mm.fit(data2)    #Constrói para cada coluna do conjunto de dados o máximo e mínimo
# Out:
# MinMaxScaler()

# %%
data_escala = mm.transform(data2)         # Retorna os dados transformados

# %%
data_escala
# Out:
# array([[0.40559441, 0.68421053, 0.50769231, 0.        ],
#        [0.36363636, 0.57894737, 0.43076923, 0.10526316],
#        [0.34965035, 0.42105263, 0.49230769, 0.13157895],
#        [       nan, 0.10526316, 0.10769231, 0.65789474],
#        [0.02797203, 0.05263158, 0.09230769, 0.63157895],
#        [0.01398601, 0.        , 0.04615385, 0.57894737],
#        [0.01398601, 0.02631579, 0.04615385, 0.68421053],
#        [0.        , 0.        , 0.        , 0.68421053],
#        [0.35664336, 0.34210526,        nan, 0.97368421],
#        [0.33566434, 0.42105263, 0.46153846, 0.89473684],
#        [0.31468531, 0.28947368, 0.50769231, 1.        ],
#        [0.33566434, 0.34210526, 0.55384615, 0.97368421],
#        [0.27272727, 0.31578947, 0.47692308, 0.86842105],
#        [0.30769231, 0.39473684, 0.56923077, 0.39473684],
#        [0.26573427, 0.47368421, 0.50769231, 0.36842105],
#        [0.27972028, 0.5       , 0.47692308, 0.36842105],
# ...
